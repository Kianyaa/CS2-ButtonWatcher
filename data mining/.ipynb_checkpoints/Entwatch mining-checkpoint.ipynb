# %%
import os
import pandas as pd
import commentjson as json
import csv

# %%
cwd = os.getcwd()
print('Current Working Directory:', cwd, end=' ')
print('\n')
print('List Directory: ', os.listdir(cwd))

#entwatch_dir = os.chdir('entwatch')
# Out:
# Current Working Directory: C:\Users\KATANA\Desktop\Github\CS2-ButtonWatcher\data mining
#
# List Directory:  ['.ipynb_checkpoints', 'entwatch', 'Entwatch mining.ipynb']

# %%
path = cwd + '\\' + os.listdir(cwd)[1]
count = 0

print('List Directory:', f"'{path}'")

for file in os.listdir(path):
    print(file)
    count += 1
print("Detect:", count, "files")
# Out:
# List Directory: 'C:\Users\KATANA\Desktop\Github\CS2-ButtonWatcher\data mining\entwatch'
# .ipynb_checkpoints
# ze_2049.jsonc
# ze_8bit.jsonc
# ze_abandoned_project_p.jsonc
# ze_aepp_nano_grid2_p.jsonc
# ze_alien_shooter.jsonc
# ze_aooka3.jsonc
# ze_aot_trost_v6r.jsonc
# ze_arcana_heart.jsonc
# ze_azathoth_p.jsonc
# ze_backrooms_deathbed_v1.jsonc
# ze_bathroom.jsonc
# ze_biohazard2_rpd_004_p.jsonc
# ze_biohazard_manor_004_p.jsonc
# ze_bioluminescent.jsonc
# ze_chicago_bean_gassy_fart_life.jsonc
# ze_christmas_infection_p.jsonc
# ze_christmas_p.jsonc
# ze_colorlicouspilar_p.jsonc
# ze_crashbandicoot_p.jsonc
# ze_cyberspace_v2.jsonc
# ze_dark_souls.jsonc
# ze_deadcore.jsonc
# ze_death_star_escape_p.jsonc
# ze_depths.jsonc
# ze_desperate_soul.jsonc
# ze_djinn.jsonc
# ze_dreamin.jsonc
# ze_escape_the_eye_p.jsonc
# ze_eternal_journey.jsonc
# ze_fapescape_p.jsonc
# ze_fapescape_rote_p.jsonc
# ze_farmhouse_p.jsonc
# ze_ffvii_mako_reactor_v6_p.jsonc
# ze_ffvii_temple_ancient.jsonc
# ze_ffxii_mt_bur_omisace_v6.jsonc
# ze_ffxii_paramina_rift.jsonc
# ze_ffxii_westersand_v8.jsonc
# ze_ffxiv_great_gubal_library.jsonc
# ze_ffxiv_reisen_temple.jsonc
# ze_forsaken_temple.jsonc
# ze_frozen_abyss.jsonc
# ze_gods_wrath_p.jsonc
# ze_goldeneye_64.jsonc
# ze_grau_p.jsonc
# ze_hydroponic_garden.jsonc
# ze_industrial_dejavu.jsonc
# ze_isla_nublar_p.jsonc
# ze_journey_p.jsonc
# ze_kraznov_poopata_p.jsonc
# ze_l0v0l_p.jsonc
# ze_last_man_standing_p.jsonc
# ze_lila_panic_escape_p.jsonc
# ze_lotr_helms_deep_p.jsonc
# ze_lotr_isengard.jsonc
# ze_lotr_minas_tiret_p.jsonc
# ze_lotr_minas_tirith_p.jsonc
# ze_lotr_mines_of_moria_p.jsonc
# ze_lotr_mount_doom_p.jsonc
# ze_mars_escape_xmas.jsonc
# ze_minecraft_dragon_castle.jsonc
# ze_minimal.jsonc
# ze_mirrors_edge_reborn_p.jsonc
# ze_mist_p.jsonc
# ze_mochi_island.jsonc
# ze_neochrome.jsonc
# ze_offliner.jsonc
# ze_onahole_p.jsonc
# ze_overlord.jsonc
# ze_palace_adventure.jsonc
# ze_parkers_pit_p.jsonc
# ze_parking_p.jsonc
# ze_permafrost.jsonc
# ze_pirates_port_royal.jsonc
# ze_platformer_p.jsonc
# ze_postal_p.jsonc
# ze_potc_p.jsonc
# ze_predator_ultimate_p.jsonc
# ze_requiem_test.jsonc
# ze_rizomata_p.jsonc
# ze_rtcw_ominous_rumors_p.jsonc
# ze_sandstorm_cs2.jsonc
# ze_santassination_p.jsonc
# ze_scourge_p.jsonc
# ze_scp_containment_breach.jsonc
# ze_serpentis_temple.jsonc
# ze_shroomforest2_p.jsonc
# ze_shroomforest3_p.jsonc
# ze_shroomforest_p.jsonc
# ze_sit_caelum_paradisus.jsonc
# ze_skygarden.jsonc
# ze_slender_escape_p.jsonc
# ze_squid_game.jsonc
# ze_starwars_v2fix.jsonc
# ze_steyliff_grove.jsonc
# ze_stilshrine_of_miriam.jsonc
# ze_sumai_facility_lite.jsonc
# ze_surf_danger_p.jsonc
# ze_surf_gypt_p.jsonc
# ze_surf_hp.jsonc
# ze_surf_vortex_p.jsonc
# ze_s_a_m.jsonc
# ze_tesv_skyrim_p.jsonc
# ze_tilex_ultimate_p.jsonc
# ze_toaster_p.jsonc
# ze_toy_world_final.jsonc
# ze_tyranny2.jsonc
# ze_tyranny_cs2.jsonc
# ze_uchiha_legacy.jsonc
# ze_urban_laby_of_death_p.jsonc
# ze_ut2004_convoy_p.jsonc
# ze_v0u0v_p.jsonc
# ze_verdant.jsonc
# ze_visualizer.jsonc
# ze_xenovation.jsonc
# ze_zertinan.jsonc
# Detect: 116 files

# %%
with open(path+ '\\' + 'ze_forsaken_temple.jsonc', 'r') as file:
    data = json.load(file)

# %%
item_split = []
item_unique = []
for each_item in data:
    print(each_item['name'].split(' '))
    item = each_item['name'].split(' ')
    item_split.append(item)
# Out:
# ['Heal', 'Magic']
# ['Electro', 'Magic']
# ['Water', 'Magic']
# ['Fire', 'Magic']
# ['Earth', 'Magic']
# ['Tornado', 'Magic']
# ['Gravity', 'Magic']
# ['Holy', 'Magic']
# ['Ammo', 'Magic']
# ['Fruit', 'of', 'Knowledge']
# ['Flame', 'of', 'Magic']
# ['The', 'Bait']
# ['Temple', 'Key']
# ['Zombie', 'Heal']
# ['Zombie', 'Beam']
# ['Zombie', 'Gravity']

# %%
for item in item_split:
    for item_split in item:
        item_unique.append(item_split)
item_unique

for i in item_unique:
    [print(i, end = ', ')]
# Out:
# ['Heal',
#  'Magic',
#  'Electro',
#  'Magic',
#  'Water',
#  'Magic',
#  'Fire',
#  'Magic',
#  'Earth',
#  'Magic',
#  'Tornado',
#  'Magic',
#  'Gravity',
#  'Magic',
#  'Holy',
#  'Magic',
#  'Ammo',
#  'Magic',
#  'Fruit',
#  'of',
#  'Knowledge',
#  'Flame',
#  'of',
#  'Magic',
#  'The',
#  'Bait',
#  'Temple',
#  'Key',
#  'Zombie',
#  'Heal',
#  'Zombie',
#  'Beam',
#  'Zombie',
#  'Gravity']

# %%
to_insert = ['the', 'of', 'materia'] # Lower_Case only!!!

for item in to_insert:
        item_unique.insert(0, item)

item_unique = list(set(item_unique))
item_unique
# Out:
# ['of',
#  'Electro',
#  'Ammo',
#  'Knowledge',
#  'The',
#  'Flame',
#  'Heal',
#  'Temple',
#  'Key',
#  'materia',
#  'the',
#  'Bait',
#  'Tornado',
#  'Magic',
#  'Beam',
#  'Gravity',
#  'Water',
#  'Holy',
#  'Zombie',
#  'Earth',
#  'Fruit',
#  'Fire']

# %%
filtered = [word.lower() for word in item_unique if word.lower() not in to_insert]
print(filtered)
# Out:
# ['electro', 'ammo', 'knowledge', 'flame', 'heal', 'temple', 'key', 'bait', 'tornado', 'magic', 'beam', 'gravity', 'water', 'holy', 'zombie', 'earth', 'fruit', 'fire']

# %%
with open('output.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['item_name'])  # header
    for item in filtered:
        writer.writerow([item])

# %% [markdown]
# ### Script

# %%
path = cwd + '\\' + os.listdir(cwd)[1]
count = 0

with open('output.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['item_name'])  # header


for file in os.listdir(path):
    if file.endswith('.jsonc'):
        print(file, ':', end='\n\n')
        
        with open(path+ '\\' + file, 'r') as file:
            data = json.load(file)
            
        item_split = []
        item_unique = []
        for each_item in data:
            print(each_item['name'].split(' '))
            item = each_item['name'].split(' ')
            item_split.append(item)

        print()
        
        for item in item_split:
            for item_split in item:
                item_unique.append(item_split)

        to_insert = ['the', 'of', 'materia', '1', '2'] # Lower_Case only!!!
        
        for item in to_insert:
                item_unique.insert(0, item)
        
        item_unique = list(set(item_unique))

        filtered = [word.lower() for word in item_unique if word.lower() not in to_insert]

        filtered_all.extend(filtered)

        
        count += 1
        
        if count == 116:
            break

        with open('output.csv', 'a', newline='') as f:
            writer = csv.writer(f)  # header
            for item in filtered:
                writer.writerow([item])
# Out:
# ze_2049.jsonc :
#
# ['Slow', 'Ball']
# ['Cone']
# ['Heal']
# ['Beam']
#
# ze_8bit.jsonc :
#
# ['Ammo']
# ['Fire']
# ['Mines']
# ['Stopper']
# ['Cannon', 'Ultimate']
# ['Electro']
# ['Heal']
#
# ze_abandoned_project_p.jsonc :
#
# ['Flamethrower']
# ['Turret', '1']
# ['Turret', '2']
# ['Red', 'Core']
# ['Green', 'Core']
#
# ze_aepp_nano_grid2_p.jsonc :
#
# ['Ice', 'Arrow']
# ['Star', 'Arrow']
# ['Fire', 'Arrow']
# ['Double', 'Jump']
# ['Dash', 'Hoop', '1']
# ['Dash', 'Hoop', '2']
#
# ze_alien_shooter.jsonc :
#
# ['Electro']
# ['Fire']
# ['Heal']
# ['Wind']
# ['Bio']
#
# ze_aooka3.jsonc :
#
# ['Electric', 'Magick']
# ['Fire', 'Magick']
# ['Gold', 'Magick']
# ['Heal', 'Magick']
# ['Ice', 'Magick']
# ['Kohh']
# ['Present', 'Magick']
# ['Water', 'Magick']
# ['Wind', 'Magick']
# ['Zombie', 'End', 'Magick']
# ['Zombie', 'IceFire', 'Magick']
# ['Zombie', 'Lure', 'Magick']
# ['Zombie', 'Rise', 'Magick']
# ['Zombie', 'Shackles', 'Magick']
# ['Zombie', 'Shield', 'Magick']
#
# ze_aot_trost_v6r.jsonc :
#
# ['Location']
# ['Fire']
# ['Ice']
# ['Heal']
# ['Wall']
# ['Wind']
# ['Bazooka']
# ['Zombie', 'Colossal', 'Titan']
# ['Zombie', 'Beat', 'Titan']
# ['Zombie', 'Armored', 'Titan']
# ['Zombie', 'Fat', 'Titan']
# ['Zombie', 'Fat', 'Titan']
# ['Zombie', 'Fat', 'Titan']
# ['Zombie', 'Titan']
# ['Zombie', 'Titan']
# ['Zombie', 'Jumper']
# ['Zombie', 'Jumper']
# ['Zombie', 'Jumper']
#
# ze_arcana_heart.jsonc :
#
# ['Gravity']
# ['Heal']
# ['Push']
# ['Shield']
# ['Zombie', 'Cube']
# ['Zombie', 'Heal']
# ['Zombie', 'Reverse']
# ['Zombie', 'Water']
#
# ze_azathoth_p.jsonc :
#
# ['Sword']
#
# ze_backrooms_deathbed_v1.jsonc :
#
# ['Tactical', 'Flashlight', '1']
# ['Tactical', 'Flashlight', '2']
#
# ze_bathroom.jsonc :
#
# ['Sponge', 'Builder']
# ['Mouse', 'Trap']
#
# ze_biohazard2_rpd_004_p.jsonc :
#
# ['Rocket', 'Launcher']
#
# ze_biohazard_manor_004_p.jsonc :
#
# ['Flamethrower']
#
# ze_bioluminescent.jsonc :
#
# ['Heal']
#
# ze_chicago_bean_gassy_fart_life.jsonc :
#
# ['Holy', 'Gas', 'Grenade']
# ['Chicago', 'Light']
# ['Heal']
#
# ze_christmas_infection_p.jsonc :
#
# ['Napalm', 'Candle']
# ['Tree', 'Placer']
# ['Icewall', 'Spawner']
# ['Present', 'Placer']
# ['Snowball', 'Launcher']
# ['Magical', 'Lantern']
# ['The', 'Core']
# ['Zombie', 'Christmas', 'Ogre']
# ['Zombie', 'Trampoline']
# ['Zombie', 'Heal']
# ['Zombie', 'Whirlpool', 'Summoner']
# ['Zombie', 'Fog']
# ['Zombie', 'Ice', 'Boomerang']
# ['Zombie', 'King']
# ['Hat']
# ['Penis']
# ['Banana']
#
# ze_christmas_p.jsonc :
#
# ['Heal']
# ['Gravity']
#
# ze_colorlicouspilar_p.jsonc :
#
# ['Baseball', 'Bat']
#
# ze_crashbandicoot_p.jsonc :
#
# ['Apple', 'Cannon']
#
# ze_cyberspace_v2.jsonc :
#
# ['Add']
# ['Subtract']
# ['Divide']
# ['Zombie', 'Multiply']
# ['Zombie', 'Fraction']
#
# ze_dark_souls.jsonc :
#
# ['Estus', 'Flask']
# ['Dark', 'Orb']
# ['Dark', 'Storm']
# ['Chaos', 'Storm']
# ['Fireball']
# ['Hidden', 'Body']
# ['Great', 'Heavy', 'Soul', 'Arrow']
# ['White', 'Dragon', 'Breath']
# ['Spook']
# ['Soothing', 'Sunlight']
# ['Blessed', 'Weapon']
# ['Lightning', 'Spear']
# ['Wrath', 'of', 'the', 'Gods']
# ['Blood', 'Shield']
# ['Grass', 'Crest', 'Shield']
# ['Sunlight', 'Shield']
# ['Skull', 'Lantern']
# ['Zombie', 'Black', 'Flame']
# ['Zombie', 'Rapport']
# ['Zombie', 'Power', 'Within']
# ['Zombie', 'Poison', 'Mist']
# ['Zombie', 'Toxic', 'Mist']
#
# ze_deadcore.jsonc :
#
# ['Cannon', '1']
# ['Cannon', '2']
# ['Cannon', '3']
#
# ze_death_star_escape_p.jsonc :
#
# ['Blue', 'Lightsaber']
# ['Red', 'Lightsaber']
#
# ze_depths.jsonc :
#
# ['Trail']
# ['Push']
# ['Fuel', 'Can']
#
# ze_desperate_soul.jsonc :
#
# ['Darkness']
# ['Brightness']
# ['Earthly', 'Star']
# ['Asylum']
# ['Holy']
# ['Heal']
# ['Double', 'Damage']
# ['Toxin']
# ['Wisp']
# ['Dawn']
# ['Planet', 'Befall']
# ['Ichika']
# ['Zombie', 'Rescue']
# ['Zombie', 'Heal']
# ['Zombie', 'Water']
#
# ze_djinn.jsonc :
#
# ['Tornado']
# ['Pyramid']
# ['Ammo']
# ['Sand']
# ['Heal']
#
# ze_dreamin.jsonc :
#
# ['Freezer']
# ['Heal']
# ['Wind']
# ['Snow']
# ['Zombie', 'Gravity']
# ['Zombie', 'Nuke']
# ['Zombie', 'Ice']
# ['Zombie', 'Heal']
#
# ze_escape_the_eye_p.jsonc :
#
# ['Flamethrower']
# ['Push']
#
# ze_eternal_journey.jsonc :
#
# ['Fire', 'Staff']
# ['Freeze', 'Staff']
# ['Heal', 'Staff']
# ['Tornado', 'Staff']
# ['Earth', 'Staff']
# ['Ultimate', 'Staff']
# ['Zombie', 'Fire']
# ['Zombie', 'Gravity']
# ['Zombie', 'Freeze']
# ['Zombie', 'Glasgavelen']
# ['Zombie', 'Cromcruach']
#
# ze_fapescape_p.jsonc :
#
# ['Ultimate', 'Weapon']
# ['Oreo', 'Heal']
# ['Ammo', 'Box']
# ['Flamethrower']
# ['Push', 'Gun']
# ['Explosive', 'Mines']
# ['Lego', 'Maker']
# ['Hand', 'Cannon']
# ['Grenade', 'Maker']
# ['Kim']
# ['Pass']
# ['Banana']
#
# ze_fapescape_rote_p.jsonc :
#
# ['Oreo', 'Heal']
# ['Ammo', 'Box']
# ['Push', 'Gun']
# ['Flamethrower']
# ['Electro', 'Gun']
# ['Pipe', 'Bombs']
# ['Lego', 'Maker']
# ['EyeTech', 'Launcher']
# ['EyeTech', 'Cannon']
# ['Banana']
# ['Steam']
# ['Cyka']
#
# ze_farmhouse_p.jsonc :
#
# ['Zombie', 'Tank']
# ['Barricade']
# ['Push', 'Gun']
# ['Ice', 'Gun']
# ['Plasma', 'Beam', 'Cannon']
#
# ze_ffvii_mako_reactor_v6_p.jsonc :
#
# ['Mimic', 'Materia']
# ['Bio', 'Materia']
# ['Barrier', 'Materia']
# ['Ultima', 'Materia']
# ['Wind', 'Materia']
# ['Heal', 'Materia']
# ['Ice', 'Materia']
# ['Aqua', 'Materia']
# ['Fire', 'Materia']
# ['Electro', 'Materia']
# ['Earth', 'Materia']
# ['Gravity', 'Materia']
#
# ze_ffvii_temple_ancient.jsonc :
#
# ['Ice']
# ['Earth']
# ['Fire']
# ['Wind']
# ['Heal']
# ['Poison']
# ['Crystal']
#
# ze_ffxii_mt_bur_omisace_v6.jsonc :
#
# ['Aqua', 'Magick']
# ['Cure', 'Magick']
# ['Dark', 'Magick']
# ['Fire', 'Magick']
# ['Poison', 'Magick']
# ['Sand', 'Magick']
# ['Thunder', 'Magick']
# ['Wind', 'Magick']
# ['Limit', 'Break', 'Magick']
# ['Cortahombres']
# ['Crystal', 'Shield']
# ['Devileye', 'Crossbow']
# ['Dragon', 'Whisker']
# ['Empyrean', 'Rod']
# ['Ensanguined', 'Shield']
# ['Loxley', 'Bow']
# ['Ultimate', 'Blade']
# ['Zombie', 'Judge', 'Zargabaath']
# ['Zombie', 'Judge', 'Drace']
# ['Zombie', 'Judge', 'Gabranth']
# ['Zombie', 'Damage', 'Magick']
# ['Zombie', 'Fear', 'Magick']
# ['Zombie', 'Gravity', 'Magick']
# ['Zombie', 'Invisibility', 'Magick']
#
# ze_ffxii_paramina_rift.jsonc :
#
# ['Esper', 'Mateus']
# ['Wind', 'Magick']
# ['Poison', 'Magick']
# ['Ice', 'Magick']
# ['Fire', 'Magick']
# ['Heal', 'Magick']
# ['Holy', 'Potion']
# ['Speed', 'Potion']
# ['Ammo', 'Potion']
# ['HI', 'Potion']
# ['HP', 'Potion']
# ['Zombie', 'Fire', 'Magick']
# ['Zombie', 'Frost', 'Magick']
# ['Zombie', 'Lure']
# ['Zombie', 'Warp']
#
# ze_ffxii_westersand_v8.jsonc :
#
# ['Wind', 'Magick']
# ['Heal', 'Magick']
# ['Earth', 'Magick']
# ['Fire', 'Magick']
# ['Electro', 'Magick']
# ['Water', 'Magick']
# ['Holy', 'Magick']
# ['Solo', 'Winner']
# ['Zombie', 'Ice']
# ['Zombie', 'Fire']
# ['Zombie', 'Heal']
# ['Zombie', 'Shield']
# ['Zombie', 'Lure']
# ['Zombie', 'Warp']
# ['Zombie', 'Invisibility']
# ['Zombie', 'Blind']
#
# ze_ffxiv_great_gubal_library.jsonc :
#
# ['Bio', 'Element']
# ['Electricity', 'Element']
# ['Fire', 'Element']
# ['Blackhole']
# ['Ice', 'Element']
# ['Summoner']
# ['Black', 'Mage']
# ['Sage']
# ['Speed']
# ['Zombie', 'Silence']
# ['Zombie', 'Shield']
# ['Zombie', 'Heal']
# ['Zombie', 'Gravity']
#
# ze_ffxiv_reisen_temple.jsonc :
#
# ['Wind']
# ['Gravity']
# ['Heal']
# ['Water']
# ['Crystal']
# ['Earth']
# ['Fire']
# ['Electro']
# ['Ice']
#
# ze_forsaken_temple.jsonc :
#
# ['Heal', 'Magic']
# ['Electro', 'Magic']
# ['Water', 'Magic']
# ['Fire', 'Magic']
# ['Earth', 'Magic']
# ['Tornado', 'Magic']
# ['Gravity', 'Magic']
# ['Holy', 'Magic']
# ['Ammo', 'Magic']
# ['Fruit', 'of', 'Knowledge']
# ['Flame', 'of', 'Magic']
# ['The', 'Bait']
# ['Temple', 'Key']
# ['Zombie', 'Heal']
# ['Zombie', 'Beam']
# ['Zombie', 'Gravity']
#
# ze_frozen_abyss.jsonc :
#
# ['Mapper', 'Knife']
# ['Heal', 'Staff']
# ['Classic', 'Bow']
# ['Ice', 'Bow']
# ['Explosive', 'Bow']
# ['Electric', 'Bow']
# ['Zombie', 'Freezer']
# ['Zombie', 'Gravity']
# ['Zombie', 'Dragon']
#
# ze_gods_wrath_p.jsonc :
#
# ['Burner', 'Gun']
# ['Fire', 'Bow', '1']
# ['Fire', 'Bow', '2']
#
# ze_goldeneye_64.jsonc :
#
# ['Heal']
# ['Golden', 'Gun']
# ['Throwing', 'Knife']
# ['RPG']
#
# ze_grau_p.jsonc :
#
# ['Outline']
# ['Zombie', 'Slow', '1']
# ['Zombie', 'Slow', '2']
# ['Zombie', 'Speed']
#
# ze_hydroponic_garden.jsonc :
#
# ['Beam']
# ['Cube']
# ['Shield']
# ['Zombie', 'Stars']
# ['Zombie', 'Heal']
# ['Zombie', 'Beam']
# ['Zombie', 'Gravity']
#
# ze_industrial_dejavu.jsonc :
#
# ['Cooler']
# ['Laser', 'Wall']
# ['Flamethrower']
# ['Push', 'Gun']
# ['Ammo', 'Box']
# ['Banana']
# ['Love', 'Machinegun']
# ['Hat']
# ['Free', 'Bird']
# ['Zombie', 'Heal']
# ['Zombie', 'Rage']
# ['Zombie', 'Vortex']
#
# ze_isla_nublar_p.jsonc :
#
# ['Shotgun']
# ['Shotgun']
# ['Health', 'Kit']
#
# ze_journey_p.jsonc :
#
# ['Abyssal', 'Orb']
# ['Lightning', 'Orb']
# ['Gust', 'Orb']
# ['Glacial', 'Orb']
# ['Divine', 'Orb']
# ['Burning', 'Orb']
# ['Celestial', 'Embrace']
#
# ze_kraznov_poopata_p.jsonc :
#
# ['Basketball']
# ['Penis']
#
# ze_l0v0l_p.jsonc :
#
# ['l0v0l']
# ['Heal']
# ['Infinite', 'Ammo']
# ['Wind']
# ['Slower', 'Sphere']
# ['Rainbow', 'Beam']
# ['Poison', 'Toilet']
# ['Wind', 'Toilet']
# ['Fire', 'Toilet']
# ['Electric', 'Toilet']
# ['Water', 'Toilet']
# ['Earth', 'Toilet']
# ['Gravity', 'Toilet']
# ['Ice', 'Toilet']
# ['Zombie', 'Heal']
# ['Zombie', 'Gravity']
#
# ze_last_man_standing_p.jsonc :
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[187], line 14
#      11 print(file, ':', end='\n\n')
#      13 with open(path+ '\\' + file, 'r') as file:
# ---> 14     data = json.load(file)
#      16 item_split = []
#      17 item_unique = []
#
# File c:\users\katana\appdata\local\programs\python\python39\lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File c:\users\katana\appdata\local\programs\python\python39\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File c:\users\katana\appdata\local\programs\python\python39\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File c:\users\katana\appdata\local\programs\python\python39\lib\json\decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting property name enclosed in double quotes: line 3 column 43 (char 50)

# %%
# Load the CSV into a DataFrame
df = pd.read_csv('output.csv')

# Convert the column to a list, remove duplicates using set, and save back to CSV
unique_items = list(set(df['item_name']))

# Create a dictionary with the key 'item_name' and the list as its value
data_dict = {'item_name': unique_items}

# Convert the dictionary into a JSON format
json_data = json.dumps(data_dict, indent=4)

# Add comments manually in JSONC format (JSON does not support comments natively, but JSONC allows them)
jsonc_data = f"// This is a list of items name updated 6/04/2025\n{json_data}"

# Save it to a JSONC file
file_path = 'data_item_names.jsonc'
with open(file_path, 'w') as file:
    file.write(jsonc_data)

file_path  # Return the file path as confirmation
# Out:
# 'data.jsonc'

# %%
unique_items
# Out:
# ['box',
#  'abyssal',
#  'explosive',
#  'cure',
#  'location',
#  'barricade',
#  'gun',
#  'esper',
#  'burner',
#  'light',
#  'holy',
#  'solo',
#  'frost',
#  'christmas',
#  'soul',
#  'blue',
#  'sand',
#  'burning',
#  'multiply',
#  'lantern',
#  'magical',
#  'icefire',
#  'black',
#  'skull',
#  'sword',
#  'blackhole',
#  'ammo',
#  'armored',
#  'spook',
#  'turret',
#  'tactical',
#  'mist',
#  'trampoline',
#  'body',
#  'bombs',
#  'silence',
#  'invisibility',
#  'gabranth',
#  'flask',
#  'mimic',
#  '3',
#  'bait',
#  'mouse',
#  'freeze',
#  'jump',
#  'crossbow',
#  'divine',
#  'wrath',
#  'divide',
#  'within',
#  'spear',
#  'electric',
#  'toxic',
#  'stopper',
#  'vortex',
#  'laser',
#  'shield',
#  'candle',
#  'break',
#  'celestial',
#  'green',
#  'dash',
#  'planet',
#  'barrier',
#  'fraction',
#  'ensanguined',
#  'zargabaath',
#  'grass',
#  'drace',
#  'throwing',
#  'weapon',
#  'trail',
#  'brightness',
#  'ichika',
#  'beat',
#  'limit',
#  'embrace',
#  'magic',
#  'sponge',
#  'empyrean',
#  'crest',
#  'potion',
#  'whirlpool',
#  'tank',
#  'outline',
#  'blade',
#  'whisker',
#  'blind',
#  'king',
#  'key',
#  'cannon',
#  'lightsaber',
#  'glasgavelen',
#  'colossal',
#  'basketball',
#  'rpg',
#  'push',
#  'chaos',
#  'warp',
#  'add',
#  'mateus',
#  'shackles',
#  'cortahombres',
#  'kit',
#  'lure',
#  'l0v0l',
#  'slow',
#  'banana',
#  'knife',
#  'titan',
#  'hand',
#  'maker',
#  'machinegun',
#  'freezer',
#  'sphere',
#  'arrow',
#  'fruit',
#  'magick',
#  'befall',
#  'ultimate',
#  'wall',
#  'gust',
#  'sage',
#  'health',
#  'rescue',
#  'heavy',
#  'estus',
#  'snow',
#  'placer',
#  'mage',
#  'tree',
#  'oreo',
#  'reverse',
#  'electricity',
#  'summoner',
#  'gravity',
#  'electro',
#  'gold',
#  'hat',
#  'aqua',
#  'shotgun',
#  'hoop',
#  'mapper',
#  'white',
#  'subtract',
#  'lego',
#  'devileye',
#  'sunlight',
#  'red',
#  'earth',
#  'darkness',
#  'ice',
#  'soothing',
#  'hidden',
#  'bio',
#  'steam',
#  'loxley',
#  'beam',
#  'love',
#  'glacial',
#  'flame',
#  'golden',
#  'hi',
#  'apple',
#  'nuke',
#  'gods',
#  'bird',
#  'gas',
#  'fog',
#  'knowledge',
#  'orb',
#  'flashlight',
#  'cube',
#  'wind',
#  'ogre',
#  'launcher',
#  'dawn',
#  'double',
#  'cone',
#  'water',
#  'dark',
#  'element',
#  'infinite',
#  'builder',
#  'thunder',
#  'wisp',
#  'heal',
#  'free',
#  'core',
#  'ultima',
#  'bazooka',
#  'fire',
#  'penis',
#  'fuel',
#  'rod',
#  'can',
#  'pyramid',
#  'napalm',
#  'power',
#  'bow',
#  'baseball',
#  'rapport',
#  'plasma',
#  'end',
#  'lightning',
#  'toxin',
#  'breath',
#  'asylum',
#  'bat',
#  'great',
#  'earthly',
#  'judge',
#  'rainbow',
#  'trap',
#  'pipe',
#  'speed',
#  'spawner',
#  'damage',
#  'winner',
#  'grenade',
#  'chicago',
#  'hp',
#  'fat',
#  'jumper',
#  'toilet',
#  'present',
#  'temple',
#  'stars',
#  'boomerang',
#  'ball',
#  'dragon',
#  'mines',
#  'blood',
#  'classic',
#  'rocket',
#  'fireball',
#  'rage',
#  'kohh',
#  'cooler',
#  'tornado',
#  'rise',
#  'zombie',
#  'storm',
#  'staff',
#  'snowball',
#  'cromcruach',
#  'kim',
#  'pass',
#  'eyetech',
#  'cyka',
#  'flamethrower',
#  'blessed',
#  'icewall',
#  'star',
#  'crystal',
#  'slower',
#  'fear',
#  'poison']

# %%
# Out:
# 'data.jsonc'
